# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing Pandas and Numpy into my Notebook using 'import'.

# %%
df=pd.read_csv('/content/sports_uncleaned_5000rows (2).csv')

# %% [markdown]
# Reading my dataset using pandas library

# %%
df
# Out:
#       Player_ID  Match_ID Player_Name       Team    Country   Age  Gender  \
# 0          1102      5082         NaN        CSK      india  17.0    male
# 1          1179      5034       Virat        KKR      india  23.0    Male
# 2          1092      5195      Rohit         RCB  sri lanka  69.0  female
# 3          1014      5068      Bumrah        KKR        NaN  60.0     mal
# 4          1106      5128    Joe Root     Lakers    England  39.0   femal
# ...         ...       ...         ...        ...        ...   ...     ...
# 4995       1198      5139         NaN        NaN  sri lanka  29.0     mal
# 4996       1194      5100      Bumrah        NaN      india  57.0     Mle
# 4997       1108      5022       Smith  Barcelona    England  34.0    male
# 4998       1046      5199      Rohit         CSK  Australia  15.0   Other
# 4999       1083      5111      Bumrah        KKR    England  43.0     mal
#
#         Coach_Name  Sport_Type  Match_Date  ...  Feedback_Score  Fan_ID  \
# ...

# %%
print(df.to_string())
# Out:
#       Player_ID  Match_ID Player_Name       Team    Country   Age  Gender    Coach_Name  Sport_Type  Match_Date  Match_Fee   Bonus  Sponsorship_Amount  Score  Assists  Goals  Wickets  Ticket_Sales  Merch_Sales      Venue Weather Win_Status  Rating  Feedback_Score  Fan_ID  Payment_Mode  Fan_Purchase_Amount  Minutes_Played  Matches_Played      Fan_Email     Fan_Phone  Fan_Count  Merch_ID
# 0          1102      5082         NaN        CSK      india  17.0    male  Rahul Dravid    Football  13-02-2023        NaN     NaN            287941.0     13        0      1        5       37356.0          NaN    Chennai                NaN     4.6             NaN   81006           NaN               8970.0             1.0               3            NaN  1.234500e+04       2337        78
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Identifying any Duplicated rows are there in my dataset.

# %%
df['Match_Fee']=df['Match_Fee'].fillna(df['Match_Fee'].mean())

# %% [markdown]
# Filling with mean(average) values in the 'Match_Fee' column in the Null values.

# %%
df['Match_Fee']=df['Match_Fee'].round().astype(int)

# %% [markdown]
# Changing the datatype og "Match_Fee" column into integer.

# %%
for x in df.index:
  if df.loc[x,'Match_Fee']<0:
    df.drop(x,inplace=True)

# %% [markdown]
# Remove rows where 'Match_Fee' column has values less than 0 using for loop function.

# %%
df['Match_Fee'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Bonus']=df['Bonus'].fillna(df['Match_Fee'].mean())

# %% [markdown]
# Filling with mean(average) values in the 'Bonus' column in the Null values.

# %%
df['Bonus']=df['Bonus'].round().astype(int)

# %% [markdown]
# Changing the datatype og "Bonus" column into integer.

# %%
for x in df.index:
  if df.loc[x,'Bonus']<0:
    df.drop(x,inplace=True)

# %% [markdown]
# Remove rows where 'Bonus' column has values in negative i.e less than 0 using for loop function.

# %%
df['Bonus'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %% [markdown]
# Filling with mean(average) values in the 'Age' column in the Null values.

# %%
df['Age']=df['Age'].round().astype(int)

# %% [markdown]
# Changing the datatype og "Age" column into integer.

# %%
df['Age'].isna().sum()
# Out:
# np.int64(0)

# %%
for x in df.index:
  if df.loc[x,'Age']<10 or df.loc[x,'Age']>60:
    df.drop(x,inplace=True)

# %% [markdown]
# Remove rows where 'Age' column has values Less than 10 and greater than 60 using for loop function.

# %%
df['Feedback_Score']=df['Feedback_Score'].fillna(df['Feedback_Score'].mean())

# %% [markdown]
# Filling with mean(average) values in the 'feedback_Score' column in the Null values.

# %%
df['Feedback_Score']=df['Feedback_Score'].round().astype(int)

# %% [markdown]
# Changing the datatype og "Feedback_Score" column into integer

# %%
for x in df.index:
  if df.loc[x,'Feedback_Score']<=0 or df.loc[x,'Feedback_Score']>5:
    df.drop(x,inplace=True)

# %% [markdown]
# Remove rows where 'Feedback_Score' column has values Outside of 1-5, which is less than 1 and greater than 5 using for loop function.

# %%
df['Ticket_Sales']=df['Ticket_Sales'].fillna(df['Ticket_Sales'].mean())

# %% [markdown]
# Filling with mean(average) values in the 'Tick_Sales' column in the Null values.

# %%
df['Ticket_Sales']=df['Ticket_Sales'].round().astype(int)

# %% [markdown]
# Changing the datatype og "Ticket_Sales" column into integer

# %%
for x in df.index:
  if df.loc[x,'Ticket_Sales']>50000:
    df.drop(x,inplace=True)

# %% [markdown]
# Remove rows where 'Ticket_Sales' column has values greater than 50000 using for loop function.

# %%
df['Player_Name'] = (df['Player_Name'].str.strip())

# %% [markdown]
# Removing extra spaces in the 'Player_Name' column values using strip().

# %%
df['Player_Name'] = df['Player_Name'].replace(r'^\s*$', 'Anonymous', regex=True)

# %% [markdown]
# Changing all type possible empty, wrong values into 'Anonymous' using replace().

# %%
df['Player_Name']=df['Player_Name'].fillna(method='bfill')
# Out:
# /tmp/ipython-input-1787172918.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Player_Name']=df['Player_Name'].fillna(method='bfill')

# %% [markdown]
# Filling missing null values using backfill method.

# %%
df['Player_Name'].unique()
# Out:
# array(['Virat', 'Bumrah', 'Joe Root', 'Smith', 'Hardik', 'Ronaldo',
#        'Anonymous', 'Rohit', 'Messi', 'Dhoni'], dtype=object)

# %% [markdown]
# Checking the 'Player_Name' column values has unique values.

# %%
df['Player_Name'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Team']=df['Team'].fillna(method='ffill')
# Out:
# /tmp/ipython-input-2775853044.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Team']=df['Team'].fillna(method='ffill')

# %% [markdown]
# Filling missing null values using frontfill method.

# %%
df['Team'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Gender'] = (df['Gender'].str.strip().str.title())

# %% [markdown]
# Removing extra spaces in column values and column name in the 'Gender' column.

# %%
df['Gender'] = (df['Gender'].replace({'Mal': 'Male', 'Mle': 'Male', 'Femal': 'Female'}))

# %% [markdown]
# Correcting the wrong typos in 'Gender' column using replace ().

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Other', 'Female'], dtype=object)

# %%
df['Gender'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Country'] = (df['Country'].str.strip().str.title())

# %% [markdown]
# Removing extra spaces in column values and column name in the 'Country' column.

# %%
df['Country'] = df['Country'].fillna(df['Country'].mode()[0])

# %% [markdown]
# Filling the missing null values in the 'Country' column using mode(most repeated value) function.

# %%
df['Country'].unique()
# Out:
# array(['India', 'Australia', 'Sri Lanka', 'England'], dtype=object)

# %%
df['Country'].isna().sum()
# Out:
# np.int64(0)

# %%
m = df.groupby('Player_Name')['Country'].nunique()
m
# Out:
# Player_Name
# Anonymous    4
# Bumrah       4
# Dhoni        4
# Hardik       4
# Joe Root     4
# Messi        4
# Rohit        4
# Ronaldo      4
# Smith        4
# Virat        4
# Name: Country, dtype: int64

# %% [markdown]
# Identifying player names appearing with multiple countries using group by()

# %%
df['Coach_Name'] = (df['Coach_Name'].str.strip().str.title())

# %% [markdown]
# Removing extra spaces in column values and column name in the 'Coach_Name' column.

# %%
df['Coach_Name']=df['Coach_Name'].replace({'':'Unknown Coach'})

# %% [markdown]
# Filling the empty values(' ') with 'unknown coach' in the coach_name column using replace().

# %%
df['Coach_Name'] = df['Coach_Name'].fillna(df['Coach_Name'].mode()[0])

# %% [markdown]
# Filling the missing null values in the 'Coach_Name' column using mode(most repeated value) function.

# %%
df['Coach_Name'].unique()
# Out:
# array(['Rahul Dravid', 'Unknown Coach', 'John Smith'], dtype=object)

# %%
df['Coach_Name'].value_counts()
# Out:
# Coach_Name
# Unknown Coach    1718
# John Smith        410
# Rahul Dravid      392
# Name: count, dtype: int64

# %%
df['Coach_Name'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Sport_Type'] = (df['Sport_Type'].replace({'footbal': 'Football', 'basktball': 'Basketball', '': 'other',' ':'other'}))

# %% [markdown]
# Identifying the wrong typos and fills with coreect sentences using replce() in the 'Sport_Type' column.

# %%
df['Sport_Type'] = df['Sport_Type'].fillna(df['Sport_Type'].mode()[0])

# %% [markdown]
# Filling the missing null values in the 'Sport_Type' column using mode(most repeated value) function.

# %%
df['Sport_Type'].unique()
# Out:
# array(['Football', 'Tennis', 'Basketball', 'Cricket', 'other'],
#       dtype=object)

# %%
df['Sport_Type'].isna().sum()
# Out:
# np.int64(0)

# %%
print(df['Sponsorship_Amount'].to_string())
# Out:
# 0        287941.0
# 1             NaN
# 3       1044184.0
# 5       1246406.0
# 6       1394214.0
# 7             NaN
# 8        730707.0
# 9             NaN
# 10       835031.0
# 12            NaN
# 18            NaN
# 19       996837.0
# 20       597941.0
# 22       811576.0
# 23      1389593.0
# 26            NaN
# 31            NaN
# 33       369706.0
# 34       446653.0
# 35       474567.0
# 36            NaN
# 39       786510.0
# 41       262307.0
# 43      1033361.0
# 44            NaN
# 46            NaN
# 48            NaN
# 50       220096.0
# 51      1079252.0
# 53      1243952.0
# 54            NaN
# 56            NaN
# 58      1239848.0
# 60       250729.0
# 63       713588.0
# 67            NaN
# 68            NaN
# 69       369408.0
# 70       555903.0
# 72       683275.0
# 74            NaN
# 79       534886.0
# 80            NaN
# 82            NaN
# 85      1434217.0
# 87            NaN
# 89            NaN
# 91      1156111.0
# 92            NaN
# 94       597878.0
# ...

# %%
df['Sponsorship_Amount']=df['Sponsorship_Amount'].fillna(df['Sponsorship_Amount'].mean())

# %% [markdown]
# Filling with mean(average) values in the 'Sponsorship_Amount' column in the Null values.

# %%
df['Sponsorship_Amount']=df['Sponsorship_Amount'].round().astype(int)

# %% [markdown]
# Changing the datatype og "Sponsorshi_Amount" column into integer

# %%
df['Sponsorship_Amount'].mean()
# Out:
# np.float64(740342.130952381)

# %%
for x in df.index:
  if df.loc[x,'Sponsorship_Amount']<=0 or df.loc[x,'Sponsorship_Amount']>=1000000:
    df.loc[x,'Sponsorship_Amount']=740343

# %% [markdown]
# Replace unrealistic Sponsorship_Amount (Less than 0 or greater than 1,000,000) with its mean value.

# %%
df['Sponsorship_Amount'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Merch_Sales'] = df['Merch_Sales'].fillna(df['Merch_Sales'].mean())

# %% [markdown]
# Filling 'Merch_Sales' column null values with its mean values.

# %%
df['Merch_Sales']=df['Merch_Sales'].round().astype(int)

# %%
df['Merch_Sales'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Venue'] = (df['Venue'].replace({' ':'Gujarat'}))

# %% [markdown]
# Replcing the empty(' ') value in the 'Venue' column to 'Gujarat' using replce().

# %%
df['Venue'] = df['Venue'].fillna(df['Venue'].mode()[0])

# %% [markdown]
# Filling the missing null values with its mode(most repeatedly values) using fillna().

# %%
df['Venue'].unique()
# Out:
# array(['Chennai', 'Bangalore', 'Mumbai', 'Kolkata', 'Delhi', 'Gujarat'],
#       dtype=object)

# %%
df['Venue'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Weather'] = (df['Weather'].str.strip().str.title())

# %%
df['Weather'] = (df['Weather'].replace({'':'Unspecified'}))

# %% [markdown]
# Replcing thr empty(' ') values to 'Unspecified' in the 'weather' column.

# %%
df['Weather'] = df['Weather'].fillna(df['Weather'].mode()[0])

# %% [markdown]
# Filling the missing null values with its mode() values in the 'Weather' column.

# %%
df['Weather'].value_counts()
# Out:
# Weather
# Rainy          1402
# Unspecified     382
# Sunny           373
# Cloudy          363
# Name: count, dtype: int64

# %%
df['Weather'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Weather'].unique()
# Out:
# array(['Unspecified', 'Rainy', 'Sunny', 'Cloudy'], dtype=object)

# %%
df['Win_Status'] = (df['Win_Status'].str.strip().str.title())

# %% [markdown]
# Removing extra spaces in both the column values and the column header name usign strip() and str().

# %%
df['Win_Status']=df['Win_Status'].fillna('Win')

# %% [markdown]
# Filling the missing null values with 'Win' in the 'Win_Status' column

# %%
df['Win_Status'].unique()
# Out:
# array(['Win', 'Draw', 'Lose'], dtype=object)

# %%
df['Win_Status'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Rating'] = df['Rating'].fillna(df['Rating'].mode()[0])

# %% [markdown]
# Filling the missing null values with its mode() values in the 'Rating; column.

# %%
df['Rating']=df['Rating'].round().astype(int)

# %%
df['Rating'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Payment_Mode'] = (df['Payment_Mode'].str.strip().str.title())

# %%
df['Payment_Mode'] = (df['Payment_Mode'].replace({'Creadit Card': 'Credit Card', 'Upi': 'UPI', 'Upiid': 'UPI', '':'Netbanking'}))

# %% [markdown]
# Replacing the wrong typos into correct sentence using replce().

# %%
df['Payment_Mode']=df['Payment_Mode'].fillna('Cash')

# %% [markdown]
# Filing the missing null values with 'Cash' on the 'Payment_Mode' column using fillna().

# %%
df['Payment_Mode'].unique()
# Out:
# array(['Cash', 'Netbanking', 'Credit Card', 'UPI'], dtype=object)

# %%
df['Payment_Mode'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Fan_Purchase_Amount'] = df['Fan_Purchase_Amount'].fillna(df['Fan_Purchase_Amount'].mean())

# %% [markdown]
# Filling the 'Fan_Purchae_Amount' column with its mean() values.

# %%
df['Fan_Purchase_Amount']=df['Fan_Purchase_Amount'].round().astype(int)

# %%
df['Fan_Purchase_Amount'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Minutes_Played'] = df['Minutes_Played'].fillna(df['Minutes_Played'].mean())

# %% [markdown]
# Filling the 'Minutes_Played' column with its mean() values.

# %%
df['Minutes_Played']=df['Minutes_Played'].round().astype(int)

# %%
df['Minutes_Played'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Match_Date']=df['Match_Date'].fillna(method='ffill')
# Out:
# /tmp/ipython-input-94484209.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Match_Date']=df['Match_Date'].fillna(method='ffill')

# %% [markdown]
# Filling the empty null values in the 'Match_Date' column using backfill method.

# %%
print(df['Match_Date'].to_string())
# Out:
# 0       13-02-2023
# 1       05-12-2022
# 3       22-01-2024
# 5       12-05-2023
# 6       23-01-2024
# 7       07-08-2021
# 8       19-05-2022
# 9       08-02-2024
# 10      03-12-2023
# 12      03-12-2023
# 18      05-12-2023
# 19      03-03-2023
# 20      07-07-2023
# 22      05-12-2023
# 23      21-08-2022
# 26      14-11-2021
# 31      12-06-2021
# 33      05-12-2023
# 34      05-12-2023
# 35      21-03-2020
# 36      20-01-2022
# 39      17-05-2022
# 41      05-07-2022
# 43      10-01-2020
# 44      13-10-2022
# 46      13-01-2022
# 48      05-12-2023
# 50      22-11-2021
# 51      22-11-2021
# 53      02-03-2023
# 54      04-03-2021
# 56      25-04-2023
# 58      25-04-2023
# 60      27-05-2021
# 63      05-12-2020
# 67      20-11-2023
# 68      22-03-2020
# 69      12-05-2023
# 70      09-12-2021
# 72      05-12-2023
# 74      18-09-2022
# 79      16-09-2021
# 80      10-04-2023
# 82      31-05-2021
# 85      07-04-2020
# 87      17-05-2022
# 89      22-08-2023
# ...

# %%
df = df.drop(columns=['Fan_Phone', 'Merch_ID', 'Fan_Email'])
# In my opinion, this columns are unwanted for this dataset. So I dropped from the table

# %% [markdown]
# There is question in my dataset as "Drop irrelevant columns after cleaning".

# %%
df.columns = df.columns.str.strip().str.title()

# %%
df.reset_index(drop=True,inplace=True)

# %% [markdown]
# Fetching all matches where Match_Fee > 4000.

# %%
print(df[df['Match_Fee'] > 4000].to_string())
# Out:
#       Player_Id  Match_Id Player_Name       Team    Country  Age  Gender     Coach_Name  Sport_Type  Match_Date  Match_Fee  Bonus  Sponsorship_Amount  Score  Assists  Goals  Wickets  Ticket_Sales  Merch_Sales      Venue      Weather Win_Status  Rating  Feedback_Score  Fan_Id Payment_Mode  Fan_Purchase_Amount  Minutes_Played  Matches_Played  Fan_Count
# 23         1063      5004       Messi        CSK      India   28  Female  Unknown Coach  Basketball  10-01-2020       4086   1343              740343    122        5      4        0         10987        12869      Delhi        Rainy        Win       7               4   82435         Cash                11031              60              10       2302
# ...

# %% [markdown]
# Fetching all feddback_score' <3

# %%
print(df[df['Feedback_Score'] < 3].to_string())
# Out:
#       Player_Id  Match_Id Player_Name       Team    Country  Age  Gender     Coach_Name  Sport_Type  Match_Date  Match_Fee  Bonus  Sponsorship_Amount  Score  Assists  Goals  Wickets  Ticket_Sales  Merch_Sales      Venue      Weather Win_Status  Rating  Feedback_Score  Fan_Id Payment_Mode  Fan_Purchase_Amount  Minutes_Played  Matches_Played  Fan_Count
# 5          1020      5187       Virat        CSK  Australia   33    Male  Unknown Coach  Basketball  07-08-2021       1907   2338              740342    121        9      1        3          8839         3104    Chennai       Cloudy        Win       7               1   82657  Credit Card                 9722              66              23       4372
# ...

# %% [markdown]
# Fetching players from India with matches > 10.

# %%
df.loc[(df['Country'] == 'India') & (df['Matches_Played'] > 10), ['Player_Name']]
# Out:
#      Player_Name
# 1          Virat
# 7         Hardik
# 8          Virat
# 14      Joe Root
# 18        Bumrah
# ...          ...
# 2505       Messi
# 2508     Ronaldo
# 2513    Joe Root
# 2515       Smith
# 2516      Bumrah
#
# [721 rows x 1 columns]

# %% [markdown]
# Fetching VIP ticket buyers where Ticket_Sales > 5000.

# %%
print(df[df['Ticket_Sales'] > 5000].to_string())
# Out:
#       Player_Id  Match_Id Player_Name       Team    Country  Age  Gender     Coach_Name  Sport_Type  Match_Date  Match_Fee  Bonus  Sponsorship_Amount  Score  Assists  Goals  Wickets  Ticket_Sales  Merch_Sales      Venue      Weather Win_Status  Rating  Feedback_Score  Fan_Id Payment_Mode  Fan_Purchase_Amount  Minutes_Played  Matches_Played  Fan_Count
# 0          1102      5082       Virat        CSK      India   17    Male   Rahul Dravid    Football  13-02-2023       1907   2338              287941     13        0      1        5         37356        10057    Chennai  Unspecified        Win       5               4   81006         Cash                 8970               1               3       2337
# ...

# %% [markdown]
# Fetching matches where Win_Status="Win" and Score > 100.

# %%
print(df[(df['Win_Status'] == 'Win') & (df['Score'] > 100)].to_string())
# Out:
#       Player_Id  Match_Id Player_Name       Team    Country  Age  Gender     Coach_Name  Sport_Type  Match_Date  Match_Fee  Bonus  Sponsorship_Amount  Score  Assists  Goals  Wickets  Ticket_Sales  Merch_Sales      Venue      Weather Win_Status  Rating  Feedback_Score  Fan_Id Payment_Mode  Fan_Purchase_Amount  Minutes_Played  Matches_Played  Fan_Count
# 5          1020      5187       Virat        CSK  Australia   33    Male  Unknown Coach  Basketball  07-08-2021       1907   2338              740342    121        9      1        3          8839         3104    Chennai       Cloudy        Win       7               1   82657  Credit Card                 9722              66              23       4372
# ...

# %% [markdown]
# Fetching cricket players with Wickets > 3.

# %%
print(df[(df['Sport_Type'] == 'Cricket') & (df['Wickets'] > 3)].to_string())
# Out:
#       Player_Id  Match_Id Player_Name       Team    Country  Age  Gender     Coach_Name Sport_Type  Match_Date  Match_Fee  Bonus  Sponsorship_Amount  Score  Assists  Goals  Wickets  Ticket_Sales  Merch_Sales      Venue      Weather Win_Status  Rating  Feedback_Score  Fan_Id Payment_Mode  Fan_Purchase_Amount  Minutes_Played  Matches_Played  Fan_Count
# 6          1102      5026      Hardik     Lakers  Sri Lanka   10    Male   Rahul Dravid    Cricket  19-05-2022       1907   2925              730707    106        3      1        5         30417        10057    Kolkata        Sunny       Lose       1               3   84529          UPI                17522             107              23       3147
# ...

# %% [markdown]
# Fetching football players with Goals >= 2.

# %%
print(df[(df['Sport_Type'] == 'Football') & (df['Goals'] >= 2)].to_string())
# Out:
#       Player_Id  Match_Id Player_Name       Team    Country  Age  Gender     Coach_Name Sport_Type  Match_Date  Match_Fee  Bonus  Sponsorship_Amount  Score  Assists  Goals  Wickets  Ticket_Sales  Merch_Sales      Venue      Weather Win_Status  Rating  Feedback_Score  Fan_Id Payment_Mode  Fan_Purchase_Amount  Minutes_Played  Matches_Played  Fan_Count
# 3          1071      5195    Joe Root     Lakers  Australia   20   Other  Unknown Coach   Football  12-05-2023        387   2338              740343    108        1      3        3         30278        10057     Mumbai        Sunny       Lose       1               4   81525   Netbanking                 9393              33              28        787
# ...

# %% [markdown]
# Fetching matches with Bonus + Match_Fee > 6000.

# %%
df[df['Bonus'] + df['Match_Fee'] > 6000]
# Out:
#       Player_Id  Match_Id Player_Name       Team    Country  Age  Gender  \
# 22         1107      5168       Virat         MI  Sri Lanka   20    Male
# 42         1145      5027       Virat        CSK      India   27  Female
# 51         1040      5194       Messi     Lakers  Sri Lanka   20    Male
# 55         1088      5156   Anonymous  Barcelona  Australia   60    Male
# 56         1070      5177       Messi        KKR    England   60    Male
# ...         ...       ...         ...        ...        ...  ...     ...
# 2480       1037      5056      Hardik        KKR  Australia   13   Other
# 2481       1126      5045       Smith     Lakers      India   14    Male
# 2494       1081      5076      Hardik        RCB      India   28    Male
# 2499       1122      5134      Bumrah         MI    England   12    Male
# 2507       1185      5089       Dhoni        KKR  Australia   37  Female
#
#          Coach_Name  Sport_Type  Match_Date  ...  Weather  Win_Status  Rating  \
# ...

# %% [markdown]
# Fetching players with average Rating < 4.

# %%
df.groupby('Player_Name')['Rating'].mean().loc[lambda x: x < 4]
# Out:
# Player_Name
# Anonymous    2.871094
# Bumrah       3.062044
# Dhoni        3.465021
# Hardik       3.106719
# Joe Root     3.054264
# Messi        3.291139
# Rohit        3.387500
# Ronaldo      3.270588
# Smith        3.449799
# Virat        3.219608
# Name: Rating, dtype: float64

# %% [markdown]
# Fetching matches played in Rainy weather

# %%
print(df[df['Weather'] == 'Rainy'].to_string())
# Out:
#       Player_Id  Match_Id Player_Name       Team    Country  Age  Gender     Coach_Name  Sport_Type  Match_Date  Match_Fee  Bonus  Sponsorship_Amount  Score  Assists  Goals  Wickets  Ticket_Sales  Merch_Sales      Venue Weather Win_Status  Rating  Feedback_Score  Fan_Id Payment_Mode  Fan_Purchase_Amount  Minutes_Played  Matches_Played  Fan_Count
# 2          1014      5068      Bumrah        KKR      India   60    Male  Unknown Coach  Basketball  22-01-2024       1907     67              740343     76        9      8        0         30278        14535  Bangalore   Rainy       Draw       1               4   81929  Credit Card                 9722              12               2        278
# ...

# %%
df['Total_Earning'] = (df['Match_Fee'] + df['Bonus'] + df['Sponsorship_Amount'])

# %% [markdown]
# Add Total_Earning = Match_Fee + Bonus + Sponsorship_Amount.

# %%
df['Performance_Score'] = (df['Score'] + (df['Assists'] * 2) + (df['Goals'] * 3) + (df['Wickets'] * 4))

# %% [markdown]
# Add Performance_Score = Score + (Assists2) + (Goals3) + (Wickets*4).

# %%
df['Revenue'] = (df['Ticket_Sales'] + df['Merch_Sales'])

# %% [markdown]
# Add Revenue = Ticket_Sales + Merch_Sales

# %%
df['Gender_Numeric'] = df['Gender'].replace({'Male': 1,'Female': 2,'Other': 3})
# Out:
# /tmp/ipython-input-2397959886.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender_Numeric'] = df['Gender'].replace({'Male': 1,'Female': 2,'Other': 3})

# %% [markdown]
# Encode Gender numerically (Male=1,Female=2,Other=3).

# %%
df['Win_Status Numerical'] = df['Win_Status'].replace({'Win': 1,'Draw': 0.5,'Lose': 0})
# Out:
# /tmp/ipython-input-3773348818.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Win_Status Numerical'] = df['Win_Status'].replace({'Win': 1,'Draw': 0.5,'Lose': 0})

# %% [markdown]
# Encode Win_Status numerically (Win=1,Draw=0.5,Lose=0).

# %%
print(df.to_string())
# Out:
#       Player_Id  Match_Id Player_Name       Team    Country  Age  Gender     Coach_Name  Sport_Type  Match_Date  Match_Fee  Bonus  Sponsorship_Amount  Score  Assists  Goals  Wickets  Ticket_Sales  Merch_Sales      Venue      Weather Win_Status  Rating  Feedback_Score  Fan_Id Payment_Mode  Fan_Purchase_Amount  Minutes_Played  Matches_Played  Fan_Count  Total_Earning  Performance_Score  Revenue  Gender_Numeric  Win_Status Numerical
# 0          1102      5082       Virat        CSK      India   17    Male   Rahul Dravid    Football  13-02-2023       1907   2338              287941     13        0      1        5         37356        10057    Chennai  Unspecified        Win       5               4   81006         Cash                 8970               1               3       2337         292186                 36    47413               1                   1.0
# ...

# %%
df.sort_values(by='Total_Earning', ascending=False)[['Player_Name', 'Total_Earning']].head(5)
# Out:
#      Player_Name  Total_Earning
# 1439    Joe Root        1004889
# 1769      Bumrah        1001163
# 2048       Smith        1001128
# 11     Anonymous        1000634
# 1060   Anonymous        1000222

# %% [markdown]
# Top 5 players by total earnings.

# %%
df.groupby('Team')['Wickets'].sum().sort_values(ascending=False).head(5)
# Out:
# Team
# Barcelona    1097
# RCB          1095
# Lakers       1090
# CSK          1051
# KKR          1041
# Name: Wickets, dtype: int64

# %% [markdown]
# Top 5 teams by Wickets scored.

# %%
df.groupby('Team')['Goals'].sum().sort_values(ascending=False).head(5)
# Out:
# Team
# Lakers       2008
# RCB          1902
# Barcelona    1896
# CSK          1893
# MI           1846
# Name: Goals, dtype: int64

# %% [markdown]
# 2.	Top 5 teams by goals scored.

# %%
df.groupby('Sport_Type')['Feedback_Score'].mean()
# Out:
# Sport_Type
# Basketball    3.664975
# Cricket       3.631098
# Football      3.601891
# Tennis        3.577640
# other         3.636086
# Name: Feedback_Score, dtype: float64

# %% [markdown]
# Average feedback score per sport type.

# %%
df.groupby('Team')['Bonus'].mean()
# Out:
# Team
# Barcelona    1931.944573
# CSK          1965.004762
# KKR          1954.566416
# Lakers       1933.198198
# MI           2022.167866
# RCB          1918.407862
# Name: Bonus, dtype: float64

# %% [markdown]
# Average bonus per team.

# %%
df.groupby('Payment_Mode')['Ticket_Sales'].count()
# Out:
# Payment_Mode
# Cash           641
# Credit Card    639
# Netbanking     602
# UPI            638
# Name: Ticket_Sales, dtype: int64

# %% [markdown]
# Most common payment mode among fans.

# %%
df.sort_values(by='Score', ascending=False)[['Player_Name', 'Score']].head(1)
# Out:
#      Player_Name  Score
# 1924     Ronaldo    199

# %% [markdown]
# Identify player with highest single match score.

# %%
df.loc[df['Matches_Played'] > 15, ['Player_Name', 'Matches_Played']]
# Out:
#      Player_Name  Matches_Played
# 3       Joe Root              28
# 5          Virat              23
# 6         Hardik              23
# 7         Hardik              18
# 11     Anonymous              28
# ...          ...             ...
# 2508     Ronaldo              26
# 2510      Hardik              18
# 2512       Rohit              24
# 2515       Smith              24
# 2517       Smith              22
#
# [1201 rows x 2 columns]

# %% [markdown]
# Find players with >15 matches.

# %%
df.sort_values(by='Minutes_Played', ascending=False)[['Player_Name', 'Minutes_Played']]
# Out:
#      Player_Name  Minutes_Played
# 1837      Hardik             120
# 1584       Messi             120
# 1102       Virat             120
# 696      Ronaldo             120
# 448        Smith             120
# ...          ...             ...
# 2412      Hardik               0
# 1244       Dhoni               0
# 1317       Smith               0
# 2406       Dhoni               0
# 2452   Anonymous               0
#
# [2520 rows x 2 columns]

# %% [markdown]
# Sort players by total minutes played.

# %%
df.groupby('Venue')['Matches_Played'].sum()
# Out:
# Venue
# Bangalore    14237
# Chennai       4533
# Delhi         4804
# Gujarat       4325
# Kolkata       4557
# Mumbai        4608
# Name: Matches_Played, dtype: int64

# %% [markdown]
# Identify most frequently played venue.

# %%
df.groupby(['Country', 'Sport_Type'])['Ticket_Sales'].sum()
# Out:
# Country    Sport_Type
# Australia  Basketball     2953342
#            Cricket        1414248
#            Football       4600214
#            Tennis         1625126
#            other          1537230
# England    Basketball     2875161
#            Cricket        1466634
#            Football       5146570
#            Tennis         1557550
#            other          2289159
# India      Basketball     7974773
#            Cricket        4382291
#            Football      12026212
#            Tennis         3483305
#            other          3932735
# Sri Lanka  Basketball     2785479
#            Cricket        1856331
#            Football       4981491
#            Tennis         2138184
#            other          1579041
# Name: Ticket_Sales, dtype: int64

# %% [markdown]
# Group by Country & Sport_Type → total ticket sales.

# %%
p = df.groupby('Player_Name')['Country'].nunique()
p
# Out:
# Player_Name
# Anonymous    4
# Bumrah       4
# Dhoni        4
# Hardik       4
# Joe Root     4
# Messi        4
# Rohit        4
# Ronaldo      4
# Smith        4
# Virat        4
# Name: Country, dtype: int64

# %% [markdown]
# Identify players appearing with different countries.

# %%
df['Match_Date'] = pd.to_datetime(df['Match_Date'], dayfirst=True)

# %% [markdown]
# Detect inconsistent date formats in Match_Date and standardize to YYYY-MM-DD.

# %%
print(df.to_string())
# Out:
#       Player_Id  Match_Id Player_Name       Team    Country  Age  Gender     Coach_Name  Sport_Type Match_Date  Match_Fee  Bonus  Sponsorship_Amount  Score  Assists  Goals  Wickets  Ticket_Sales  Merch_Sales      Venue      Weather Win_Status  Rating  Feedback_Score  Fan_Id Payment_Mode  Fan_Purchase_Amount  Minutes_Played  Matches_Played  Fan_Count  Total_Earning  Performance_Score  Revenue  Gender_Numeric  Win_Status Numerical
# 0          1102      5082       Virat        CSK      India   17    Male   Rahul Dravid    Football 2023-02-13       1907   2338              287941     13        0      1        5         37356        10057    Chennai  Unspecified        Win       5               4   81006         Cash                 8970               1               3       2337         292186                 36    47413               1                   1.0
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
print(df.to_string())
# Out:
#       Player_Id  Match_Id Player_Name       Team    Country  Age  Gender     Coach_Name  Sport_Type Match_Date  Match_Fee  Bonus  Sponsorship_Amount  Score  Assists  Goals  Wickets  Ticket_Sales  Merch_Sales      Venue      Weather Win_Status  Rating  Feedback_Score  Fan_Id Payment_Mode  Fan_Purchase_Amount  Minutes_Played  Matches_Played  Fan_Count  Total_Earning  Performance_Score  Revenue  Gender_Numeric  Win_Status Numerical
# 0          1102      5082       Virat        CSK      India   17    Male   Rahul Dravid    Football 2023-02-13       1907   2338              287941     13        0      1        5         37356        10057    Chennai  Unspecified        Win       5               4   81006         Cash                 8970               1               3       2337         292186                 36    47413               1                   1.0
# ...
